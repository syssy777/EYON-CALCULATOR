# %%
from tkinter import *
import tkinter.messagebox
import math

calculator_window = Tk()
calculator_window.title('Percentage Calculator')
calculator_window.title('Percentage Calculator')
calculator_window.resizable(False, False)
calculator_window.iconbitmap(r'C:\Users\Ntokozo\Downloads\hnet.com-image.ico')
calculator_window.configure(background="#e0e0eb")
calculator_window.geometry('1350x690+0+0')
frame1 = Frame(calculator_window)
frame1.place()


def help_():
    tkinter.messagebox.showinfo('Important!',
                'Please, Read Carefully The Instructions Written Above Each Frame Before Using This Application.\n'
                'To ensure the safety of all your data, please DOWNLOAD/ EXPORT at least daily all data to your local machine and \n'
                'save them into an external hard drive or cloud like google drive, yahoo dropbox e.t.c \n'
                'The manufacturer of this application is not responsible for any loss of data due to damage to \n'
                'local machine or your negligence to back up your data consistently and appropriately.')


def about_():
    tkinter.messagebox.showinfo('About!',
                'Copyright © 2020 EYON TECHNOLOGY(PTY) LTD & SYLVESTER AKLAMAVO. All Rights Reserved.\n\n'
                'We\'ve worked hard to ensure that the results presented by our application are correct, and accurately'
                ' reflect real world\n'
                'calculations based on the user supplied data. However, we do not guarantee that this will be the case '
                'in all situations.\n'
                'This application is provided “as is”, without warranty of any kind.\n'
                'Therefore,we are not responsible for any losses arising from any use of \n'
                'or reliance upon any calculations or conclusions reached using this application.\n'
                'Contact: aklamasyssy@gmail.com')


menuBar = Menu(calculator_window)
aboutMenu = Menu(menuBar, tearoff=0)
menuBar.add_cascade(label='Help', menu=aboutMenu)
aboutMenu.add_command(label='Help', command=help_)
aboutMenu.add_command(label='About', command=about_)
calculator_window.configure(menu=menuBar)


header1 = Label(calculator_window,
                text='THE PERCENTAGE OF A NUMBER FROM THE TOTAL\n % of number X from Total Y',
                bg="#e0e0eb",
                font=('arial', 7, 'bold'), bd=10).place(x=53, y=0)
frame_input = Frame(calculator_window, width=405, height=155, bg="light grey", relief=RIDGE, bd=1).place(x=5,
                                                                                                         y=40)
frame_for_buttons = Frame(calculator_window, width=405, height=38, bg="#e0e0eb", relief=RIDGE, bd=1).place(x=5,
                                                                                                           y=180)

firstNumber = StringVar()
labfirstNumber = Label(calculator_window, text='Enter The Total Value', bg="light grey",
                       font=('arial', 8, 'bold')
                       , bd=4)
labfirstNumber.place(x=10, y=62)
Text_firstNumber = Entry(calculator_window, textvariable=firstNumber, font=('arial', 16, 'bold'), bd=12)
Text_firstNumber.place(
    x=135, y=42)

secondNumber = StringVar()
labsecondNumber = Label(calculator_window, text='Enter Value', bg="light grey", font=('arial', 8, 'bold'),
                        bd=4)
labsecondNumber.place(x=10, y=102)
Text_secondNumber = Entry(calculator_window, textvariable=secondNumber, font=('arial', 16, 'bold'), bd=12)
Text_secondNumber.place(x=135, y=83)

result = StringVar()
labResult = Label(calculator_window, text='RESULT  (%)', bg="light grey", font=('arial', 9, 'bold'), bd=4)
labResult.place(x=10, y=148)
Text_Result = Entry(calculator_window, textvariable=result, font=('arial', 16, 'bold'), bd=12)
Text_Result.place(x=135, y=130)

def percent_of_a_number_from_total():
    try:

        total = float(firstNumber.get())
        number = float(secondNumber.get())
        percent = (number / total * 100)
        result.set(percent)
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def round_():
    total = float(firstNumber.get())
    number = float(secondNumber.get())
    percent = (number / total * 100)
    result.set(round(percent))

def two_decimal():
    total = float(firstNumber.get())
    number = float(secondNumber.get())
    percent = (number / total * 100)
    result.set(f'{percent:.2f}')

def clear():
    firstNumber.set('')
    secondNumber.set('')
    result.set('')

def i_exit():
    iExit = tkinter.messagebox.askyesno('Exit?', ' Confirm Exit')
    if iExit > 0:
        calculator_window.destroy()
        return

btn_answer = Button(calculator_window, text='ANSWER', font=('arial', 7, 'bold'), justify=CENTER, width=13,
                    height=2,
                    bg="#b3b3b3", bd=1,
                    command=percent_of_a_number_from_total).place(x=12, y=185)
btn_roundf = Button(calculator_window, text='ROUND FIGURE', font=('arial', 7, 'bold'), justify=CENTER, width=13,
                    height=2, bg="#b3b3b3", bd=1,
                    command=round_).place(x=114, y=185)
btn_2decimal = Button(calculator_window, width=13, text='TWO DECIMALS', font=('arial', 7, 'bold'), height=2,
                      bg="#b3b3b3", bd=1,
                      command=lambda: two_decimal()).place(x=217, y=185)
btn_reset = Button(calculator_window, width=13, text='CLEAR', font=('arial', 7, 'bold'),
                   height=2, bg="#f9bbbb", bd=1, command=clear).place(x=317, y=185)

# ==================================================== Frame 2  ===================================================
VAT = StringVar()
frame2 = Frame(calculator_window).place()
header2 = Label(calculator_window, text='THE PERCENTAGE OF A NUMBER\n Y % of number X', bg="#e0e0eb",
                font=('arial', 7, 'bold'),
                bd=10).place(x=115, y=220)

frame_input2 = Frame(calculator_window, width=405, height=155, bg="light grey", relief=RIDGE, bd=1).place(x=5,
                                                                                                          y=260)
frame_for_buttons2 = Frame(calculator_window, width=405, height=38, bg="#e0e0eb", relief=RIDGE, bd=1).place(
    x=5,
    y=405)

firstNumber2 = StringVar()
labFirstNumber2 = Label(calculator_window, text='Enter Value', bg="light grey", font=('arial', 9, 'bold'),
                        bd=4).place(x=10, y=278)
Text_firstNumber2 = Entry(calculator_window, textvariable=firstNumber2, font=('arial', 16, 'bold'),
                          bd=12).place(x=135, y=261)

secondNumber2 = StringVar()
labsecondNumber2 = Label(calculator_window, text='Percentage (%)', bg="light grey", font=('arial', 9, 'bold'),
                         bd=4).place(x=10, y=328)
Text_secondNumber2 = Entry(calculator_window, textvariable=secondNumber2, font=('arial', 16, 'bold'), width=6,
                           bd=12).place(x=135, y=310)

vatEntry = Entry(calculator_window, textvariable=VAT, font=('arial', 16, 'bold'), width=4,
                 bd=12, bg='#caf7e2', ).place(x=328, y=310)

result2 = StringVar()
discount = StringVar()
labResult2 = Label(calculator_window, text='RESULT ', bg="light grey", font=('arial', 9, 'bold'),
                   bd=4).place(x=10, y=375)
Text_result2 = Entry(calculator_window, textvariable=result2, font=('arial', 16, 'bold'), bd=12)
Text_result2.place(x=135, y=355)

def percent_of_a_number():
    try:
        percent = float(secondNumber2.get())
        number = float(firstNumber2.get())
        ans = float(((number / 100) * percent))
        result2.set(ans)
        Text_result2.configure(bg="#fcfcfc")
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def vat_include():
    VAT.set(15)
    percent = float(secondNumber2.get())
    number = float(firstNumber2.get())
    discount = float(((number / 100) * percent))
    vaT = float(number + (number / 100 * float(VAT.get())) - discount)

    result2.set(vaT)
    Text_result2.configure(bg='#caf7e2')

def discount():
    percent = float(secondNumber2.get())
    number = float(firstNumber2.get())
    answer = float(((number / 100) * percent))
    disc = number - answer
    result2.set(disc)
    Text_result2.configure(bg="#f9dbc0")

def round_2():
    percent = float(secondNumber2.get())
    number = float(firstNumber2.get())
    ans = float(((number / 100) * percent))
    result2.set(round(ans))

def two_decimal2():
    percent = float(secondNumber2.get())
    number = float(firstNumber2.get())
    ans = float(((number / 100) * percent))
    result2.set(f'{ans:.2f}')

def clear2():
    Text_result2.configure(bg="#fcfcfc")
    firstNumber2.set('')
    secondNumber2.set('')
    result2.set('')
    VAT.set('')

btn_answer2 = Button(calculator_window, text='ANSWER', font=('arial', 7, 'bold'), width=9, height=2,
                     bg="#b3b3b3",
                     bd=1,
                     command=percent_of_a_number).place(x=12, y=410)

btn_round_figure_2 = Button(calculator_window, text='ROUND FIGURE', width=13, font=('arial', 7, 'bold'),
                            height=2,
                            bg="#b3b3b3", bd=1, command=round_2).place(x=80, y=410)

btn_2decimal2 = Button(calculator_window, text='TWO DECIMALS', font=('arial', 7, 'bold'), width=13, height=2,
                       bg="#b3b3b3", bd=1,
                       command=two_decimal2).place(x=173, y=410)

btn_answer2B_discount = Button(calculator_window, text='DISCOUNT', width=10, font=('arial', 7, 'bold'),
                               height=2,
                               bg="#f9dbc0", bd=1, command=discount).place(x=264, y=410)

btn_reset4 = Button(calculator_window, text='CLEAR', width=9, font=('arial', 7, 'bold'), height=2, bg="#f9bbbb",
                    bd=1,
                    command=clear2).place(x=340, y=410)

include_btn = Button(calculator_window,
                     font=('arial', 10,), text='Incl. VAT', bg='#caf7e2', width=7, height=2, command=vat_include)
include_btn.place(x=264, y=312)

# ================================== Frame 3===================================================================

frame3 = Frame(calculator_window).place()
header3 = Label(calculator_window, text='THE PERCENTAGE DIFFERENCE OF TWO NUMBERS\n % difference of X and Y',
                bg="#e0e0eb",
                font=('arial', 7, 'bold'), bd=12).place(x=68, y=445)

frame_input3 = Frame(calculator_window, width=405, height=155, bg="light grey", relief=RIDGE, bd=1).place(x=5,
                                                                                                          y=485)
frame_for_buttons3 = Frame(calculator_window, width=405, height=38, bg="#e0e0eb", relief=RIDGE, bd=1).place(
    x=5,
    y=635)

firstNumber3 = StringVar()
labfirstNumber3 = Label(calculator_window, text='Enter Value 1', bg="light grey", font=('arial', 9, 'bold'),
                        bd=4).place(x=10, y=505)
Text_firstNumber3 = Entry(calculator_window, textvariable=firstNumber3, font=('arial', 16, 'bold'),
                          bd=12).place(
    x=135, y=486)

secondNumber3 = StringVar()
labsecondNumber3 = Label(calculator_window, text='Enter value 2', bg="light grey", font=('arial', 9, 'bold'),
                         bd=4).place(x=10, y=555)
Text_secondNumber3 = Entry(calculator_window, textvariable=secondNumber3, font=('arial', 16, 'bold'),
                           bd=12).place(
    x=135, y=538)

result3 = StringVar()
labResult3 = Label(calculator_window, text='RESULT (%)', bg="light grey", font=('arial', 9, 'bold'),
                   bd=4).place(x=10, y=605)
Text_result3 = Entry(calculator_window, textvariable=result3, font=('arial', 16, 'bold'), bd=12).place(x=135,
                                                                                                       y=583)

def percent_difference():
    try:
        x = float(firstNumber3.get())
        y = float(secondNumber3.get())
        equals = float((x - y) / ((x + y) / 2))
        ans = float(equals * 100)
        result3.set(ans)
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def round_3():
    x = float(firstNumber3.get())
    y = float(secondNumber3.get())
    equals = float((x - y) / ((x + y) / 2))
    ans = float(equals * 100)
    result3.set(round(ans))

def two_decimal3():
    x = float(firstNumber3.get())
    y = float(secondNumber3.get())
    equals = float((x - y) / ((x + y) / 2))
    ans = float(equals * 100)
    result3.set(f'{ans:.2f}')

def clear3():
    firstNumber3.set('')
    secondNumber3.set('')
    result3.set('')

btn_answer3 = Button(calculator_window, text='ANSWER', width=13, font=('arial', 7, 'bold'), height=2,
                     bg="#b3b3b3",
                     bd=1,
                     command=percent_difference).place(x=12, y=640)
btn_roundf3 = Button(calculator_window, width=13, text='ROUND FIGURE', font=('arial', 7, 'bold'), height=2,
                     bg="#b3b3b3", bd=1, command=round_3).place(x=114, y=640)
btn_2decimal3 = Button(calculator_window, width=13, text='TWO DECIMALS', font=('arial', 7, 'bold'), height=2,
                       bg="#b3b3b3", bd=1,
                       command=lambda: two_decimal3()).place(x=217, y=640)
btn_reset3 = Button(calculator_window, width=13, text='CLEAR', font=('arial', 7, 'bold'), height=2,
                    bg="#f9bbbb",
                    bd=1,
                    command=clear3).place(x=317, y=640)

# ==================================== Frame 4 ==============================================================

frame4 = Frame(calculator_window).place()
header4 = Label(calculator_window,
                text='THE PERCENTAGE OF INCREASE/ DECREASE OF TWO NUMBERS\n % of increase or decrease of X and Y',
                bg="#e0e0eb", font=('arial', 7, 'bold'), bd=1).place(x=505, y=10)

frame_input4 = Frame(calculator_window, width=445, height=155, bg="light grey", relief=RIDGE, bd=1).place(x=420,
                                                                                                          y=40)
frame_for_buttons4 = Frame(calculator_window, width=445, height=38, bg="#e0e0eb",
                           relief=RIDGE, bd=1).place(x=420, y=180)

firstNumber4 = StringVar()
labfirstNumber4 = Label(calculator_window, text='Enter Value 1', bg="light grey", font=('arial', 9, 'bold'),
                        bd=4).place(x=425, y=62)
Text_firstNumber4 = Entry(calculator_window, textvariable=firstNumber4, font=('arial', 16, 'bold'),
                          bd=12).place(
    x=590, y=42)

secondNumber4 = StringVar()
labsecondNumber4 = Label(calculator_window, text='Enter value 2', bg="light grey", font=('arial', 9, 'bold'),
                         bd=4).place(x=425, y=102)
Text_secondNumber4 = Entry(calculator_window, textvariable=secondNumber4, font=('arial', 16, 'bold'),
                           bd=12).place(
    x=590, y=83)

result4 = StringVar()
labResult4 = Label(calculator_window, text='RESULT (%)', bg="light grey", font=('arial', 10, 'bold'),
                   bd=4).place(x=425, y=148)
Text_result4 = Entry(calculator_window, textvariable=result4, font=('arial', 16, 'bold'), bd=12).place(x=590,
                                                                                                       y=130)

def percentage_of_increase():
    try:
        x = float(firstNumber4.get())
        y = float(secondNumber4.get())
        equals = float((x - y) / - x)
        ans = float(equals * 100)
        result4.set(ans)
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def percentage_of_decrease():
    try:
        x = float(firstNumber4.get())
        y = float(secondNumber4.get())
        equals = float((x - y) / x)
        ans = float(equals * 100)
        result4.set(ans)
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def round_4():
    x = float(firstNumber4.get())
    y = float(secondNumber4.get())
    equals = float((x - y) / - x)
    ans = float(equals * 100)
    result4.set(round(ans))

def two_decimal4():
    x = float(firstNumber4.get())
    y = float(secondNumber4.get())
    equals = float((x - y) / - x)
    ans = float(equals * 100)
    result4.set(f'{ans:.2f}')

def clear4():
    firstNumber4.set('')
    secondNumber4.set('')
    result4.set('')

btn_answer4 = Button(calculator_window, text='INCREASE', font=('arial', 7, 'bold'), width=10, height=2,
                     bg="#b3b3b3", bd=1,
                     command=percentage_of_increase).place(x=430, y=185)
btn_answer4B = Button(calculator_window, text='DECREASE', font=('arial', 7, 'bold'), width=11, height=2,
                      bg="#b3b3b3", bd=1,
                      command=percentage_of_decrease).place(x=511, y=185)
btn_roundf4 = Button(calculator_window, text='ROUND FIGURE', width=13, font=('arial', 7, 'bold'), height=2,
                     bg="#b3b3b3", bd=1, command=round_4).place(x=598, y=185)
btn_2decimal4 = Button(calculator_window, text='TWO DECIMALS', font=('arial', 7, 'bold'), width=13, height=2,
                       bg="#b3b3b3", bd=1,
                       command=lambda: two_decimal4()).place(x=695, y=185)
btn_reset4 = Button(calculator_window, text='CLEAR', width=10, font=('arial', 7, 'bold'), height=2, bg="#f9bbbb",
                    bd=1,
                    command=clear4).place(x=790, y=185)
# ======================================== Frame 5 ==============================================================

frame5 = Frame(calculator_window).place()
header5 = Label(calculator_window,
                text='THE PERCENTAGE CHANGE INCREASE/ DECREASE \n % increase or decrease of X',
                bg="#e0e0eb", font=('arial', 7, 'bold'), bd=1).place(x=535, y=230)

frame_input5 = Frame(calculator_window, width=445, height=155, bg="light grey", relief=RIDGE, bd=1).place(x=420,
                                                                                                          y=260)
frame_for_buttons5 = Frame(calculator_window, width=445, height=38, bg="#e0e0eb",
                           relief=RIDGE, bd=1).place(x=420, y=405)

firstNumber5 = StringVar()
labfirstNumber5 = Label(calculator_window, text='Enter Value', bg="light grey", font=('arial', 9, 'bold'),
                        bd=4).place(x=425, y=278)
Text_firstNumber5 = Entry(calculator_window, textvariable=firstNumber5, font=('arial', 16, 'bold'),
                          bd=12).place(x=590, y=262)

secondNumber5 = StringVar()
result5 = StringVar()
labsecondNumber5 = Label(calculator_window, text='Percentage (%)', bg="light grey", font=('arial', 9, 'bold'),
                         bd=4).place(x=425, y=328)
Text_secondNumber5 = Entry(calculator_window, textvariable=secondNumber5, font=('arial', 16, 'bold'),
                           bd=12).place(
    x=590, y=310)

labResult5 = Label(calculator_window, text='RESULT', bg="light grey", font=('arial', 10, 'bold'),
                   bd=4).place(x=425, y=375)
Text_result5 = Entry(calculator_window, textvariable=result5, font=('arial', 16, 'bold'), bd=12).place(x=590,y=355)

def percentage_change_increase():
    try:
        x = float(firstNumber5.get())
        y = float(secondNumber5.get())
        ans = float(x * (1 + (y * 0.01)))
        result5.set(ans)
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def percentage_change_decrease():
    try:
        x = float(firstNumber5.get())
        y = float(secondNumber5.get())
        ans = float(x * (1 - (y * 0.01)))
        result5.set(ans)
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def round_5():
    x = float(firstNumber5.get())
    y = float(secondNumber5.get())
    ans = float(x * (1 + (y * 0.01)))
    result5.set(ans)
    result5.set(round(ans))

def two_decimal5():
    x = float(firstNumber5.get())
    y = float(secondNumber5.get())
    ans = float(x * (1 + (y * 0.01)))
    result5.set(ans)
    result5.set(f'{ans:.2f}')

def clear5():
    firstNumber5.set('')
    secondNumber5.set('')
    result5.set('')

btn_answer5 = Button(calculator_window, text='INCREASE', font=('arial', 7, 'bold'), width=10, height=2,
                     bg="#b3b3b3", bd=1,
                     command=percentage_change_increase).place(x=429, y=410)
btn_answer5B = Button(calculator_window, text='DECREASE', font=('arial', 7, 'bold'), width=11, height=2,
                      bg="#b3b3b3", bd=1,
                      command=percentage_change_decrease).place(x=509, y=410)
btn_roundf5 = Button(calculator_window, text='ROUND FIGURE', font=('arial', 7, 'bold'), width=13, height=2,
                     bg="#b3b3b3", bd=1,
                     command=round_5).place(x=595, y=410)
btn_2decimal5 = Button(calculator_window, text='TWO DECIMALS', font=('arial', 7, 'bold'), height=2, width=13,
                       bg="#b3b3b3", bd=1,
                       command=lambda: two_decimal5()).place(x=692, y=410)
btn_reset5 = Button(calculator_window, text='CLEAR', font=('arial', 7, 'bold'), width=10, height=2, bg="#f9bbbb",
                    bd=1,
                    command=clear5).place(x=790, y=410)

# ============================================== Frame 6 ==========================================================

frame6 = Frame(calculator_window).place()
header6 = Label(calculator_window, text="THE AVERAGE OF ANY LIST OF VALUES. SEPARATE EACH VALUE WITH A '+'\n"
                                        "Average of A+B+C+D .....",
                bg="#e0e0eb", font=('arial', 7, 'bold'), bd=12).place(x=460, y=445)

frame_input6 = Frame(calculator_window, width=445, height=155, bg="light grey", relief=RIDGE, bd=1).place(x=420,
                                                                                                          y=485)
frame_for_buttons6 = Frame(calculator_window, width=445, height=38, bg="#e0e0eb", relief=RIDGE, bd=1).place(
    x=420,
    y=635)

firstNumber6 = StringVar()
labfirstNumber6 = Label(calculator_window, text='Enter Values', bg="light grey", font=('arial', 9, 'bold'),
                        bd=4).place(x=425, y=505)
Text_firstNumber6 = Entry(calculator_window, textvariable=firstNumber6, font=('arial', 16, 'bold'),
                          bd=12).place(x=590, y=486)

secondNumber6 = StringVar()
labsecondNumber6 = Label(calculator_window, text='Number of items in the list', bg="light grey",
                         font=('arial', 8, 'bold'),
                         bd=4).place(x=425, y=555)
Text_secondNumber6 = Entry(calculator_window, textvariable=secondNumber6, state=DISABLED,
                           font=('arial', 16, 'bold'),
                           bd=12).place(x=590, y=538)
secondNumber6.set('-------------------------------------------------')

result6 = StringVar()
labResult6 = Label(calculator_window, text='RESULT', bg="light grey", font=('arial', 10, 'bold'),
                   bd=4).place(x=425, y=605)
Text_result6 = Entry(calculator_window, textvariable=result6, font=('arial', 16, 'bold'), bd=12).place(x=590,y=583)

def average():
    try:

        list_ = [float(i) for i in firstNumber6.get().split('+')]
        median = (sum(list_) / len(list_))
        result6.set(median)

        secondNumber6.set(len(list_))
    except ValueError:
        print('Invalid input.Digits Only.')
    except KeyboardInterrupt:
        print('WARNING!!! Do not try to stop the program.')

def round_6():
    list_ = []
    list_ = [float(i) for i in firstNumber6.get().split('+')]
    median = sum(list_) / len(list_)
    result6.set(f'{median:.0f}')

def two_decimal6():
    list_ = []
    list_ = [float(i) for i in firstNumber6.get().split('+')]
    median = sum(list_) / len(list_)
    result6.set(f'{median:.2f}')

def clear6():
    firstNumber6.set('')
    secondNumber6.set('-------------------------------------------------')
    result6.set('')

btn_answer6 = Button(calculator_window, text='ANSWER', width=13, font=('arial', 7, 'bold'), height=2,
                     bg="#b3b3b3",
                     bd=1,
                     command=lambda: average()).place(x=430, y=640)
btn_roundf6 = Button(calculator_window, width=13, text='ROUND FIGURE', font=('arial', 7, 'bold'), height=2,
                     bg="#b3b3b3", bd=1,
                     command=lambda: round_6()).place(x=533, y=640)
btn_2decimal6 = Button(calculator_window, width=13, text='TWO DECIMALS', font=('arial', 7, 'bold'), height=2,
                       bg="#b3b3b3", bd=1,
                       command=lambda: two_decimal6()).place(x=638, y=640)
btn_reset6 = Button(calculator_window, width=18, text='CLEAR', font=('arial', 7, 'bold'), height=2,
                    bg="#f9bbbb",
                    bd=1,
                    command=clear6).place(x=740, y=640)

# ================================ Frame 7/ Standard calculator ===================================================

frame7 = Frame(calculator_window).place()
header7 = Label(calculator_window, text='STANDARD CALCULATOR', bg="#e0e0eb", font=('arial', 10, 'bold'),
                bd=12).place(x=1030,y=0)
txtDisplay = Entry(calculator_window, font=('arial', 20, 'bold'), bg="#d9d9d9", bd=20, width=28, justify=RIGHT)
txtDisplay.place(x=880, y=40)
txtDisplay.insert(0, '0')

class Calc:

    def __init__(self):
        self.arithmetic_operator = " "
        self.result = False
        self.check_sum = False
        self.total = 0
        self.current = 
        self.input_value = True

    def number_enter(self, num):
        try:
            self.result = False
            first_num = txtDisplay.get()
            second_num = str(num)
            if self.input_value:
                self.current = second_num
                self.input_value = False
            else:
                if second_num == '.':
                    if second_num in first_num:
                        return
                self.current = first_num + second_num
            self.display(self.current)
        except ValueError:
            print('Invalid input.Digits Only.')
        except KeyboardInterrupt:
            print('WARNING!!! Do not try to stop the program.')

    def sum_of_total(self):
        self.result = True
        self.current = float(self.current)
        if self.check_sum:
            self.valid_function()
        else:
            # self.total = (txtDisplay.get())
            self.current = str(self.total)
            # self.valid_function()

    def valid_function(self):
        if self.arithmetic_operator == 'add':
            self.total += self.current

        if self.arithmetic_operator == 'minus':
            self.total -= self.current
        if self.arithmetic_operator == 'multiply':
            self.total *= self.current
        if self.arithmetic_operator == 'divide':
            self.total /= self.current
        self.input_value = True
        self.check_sum = False
        self.display(self.total)

    def operation(self, arithmetic_operator):

        self.current = float(self.current)
        self.arithmetic_operator = self.current

        if self.check_sum:
            self.valid_function()
        elif not self.result:
            self.total = self.current
            self.input_value = True
        self.check_sum = True

        self.arithmetic_operator = arithmetic_operator

        self.result = False

    def display(self, value):
        try:
            txtDisplay.delete(0, END)
            txtDisplay.insert(0, value)
        except ValueError:
            print('Invalid input.Digits Only.')
        except KeyboardInterrupt:
            print('WARNING!!! Do not try to stop the program.')

    def clear_entry(self):
        self.result = False
        self.current = "0"
        self.display(0)
        self.input_value = True

    def backspace(self):
        self.current = self.current[0:len(self.current) - 1]
        if self.current == "":
            self.input_value = True
            self.current = '0'
        self.display(self.current)

    def clear_all_entry(self):
        self.clear_entry()
        self.total = "0"

    def plus_minus(self):
        self.result = False

        self.current = -float((txtDisplay.get()))
        self.display(self.current)

    def square_root(self):
        self.result = False

        self.current = math.sqrt(float(txtDisplay.get()))
        self.display(self.current)

added_value = Calc()

# ==============================================number pad=======================================================

btn7 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='7', pady=1,
               command=lambda: added_value.number_enter(7))).place(x=880, y=207)
btn8 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='8', pady=1,
               command=lambda: added_value.number_enter(8))).place(x=996, y=207)
btn9 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='9', pady=1,
               command=lambda: added_value.number_enter(9))).place(x=1112, y=207)
btn4 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='4', pady=1,
               command=lambda: added_value.number_enter(4))).place(x=880, y=299)
btn5 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='5', pady=1,
               command=lambda: added_value.number_enter(5))).place(x=996, y=299)
btn6 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='6', pady=1,
               command=lambda: added_value.number_enter(6))).place(x=1112, y=299)
btn1 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='1', pady=1,
               command=lambda: added_value.number_enter(1))).place(x=880, y=390)
btn2 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='2', pady=1,
               command=lambda: added_value.number_enter(2))).place(x=996, y=390)
btn3 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=6, text='3', pady=1,
               command=lambda: added_value.number_enter(3))).place(x=1112, y=390)

# ==============================================================================================================
btnCE = (
    Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, text='DEL',
           pady=1,
           command=added_value.clear_all_entry)).place(x=880, y=117)

btnBackspace = (
    Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, text='←',
           pady=1,
           command=added_value.backspace)).place(x=996, y=117)

btnSqRoot = (
    Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, text='√',
           pady=1,
           command=added_value.square_root)).place(x=1112, y=117)

# =============================================== arithmetic operator ============================================
btnDiv = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, pady=1,
                 text=chr(247), command=lambda: added_value.operation('divide')))
btnDiv.place(x=1228, y=117)

btnMulti = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, pady=1,
                   text=chr(42), command=lambda: added_value.operation('multiply')))
btnMulti.place(x=1228, y=209)

btnSub = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, pady=1,
                 text=chr(45), command=lambda: added_value.operation('minus')))
btnSub.place(x=1228, y=301)

btnAdd = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, pady=1,
                 text=chr(43), command=lambda: added_value.operation('add')))
btnAdd.place(x=1228, y=392)

# =============================================== row 5 ==========================================================
btn0 = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bd=4, text='0', pady=1,
               command=lambda: added_value.number_enter(0)))
btn0.place(x=996, y=484)

btnDot = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, text='.',pady=1,
           command=lambda: added_value.number_enter('.'))).place(x=1112, y=484)

btnPM = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, pady=1,
                text=chr(177), command=added_value.plus_minus)).place(x=880, y=484)

btnEquals = (Button(calculator_window, width=6, height=2, font=('arial', 20, 'bold'), bg="#b3b3b3", bd=4, pady=1,
           text='=', command=added_value.sum_of_total)).place(x=1228, y=484)

btn_exit = Button(calculator_window, text='EXIT', font=('arial', 20, 'bold'), width=15, bg="#ff3333",
                  bd=10, command=i_exit).place(x=980, y=600)
calculator_window.configure(menu=menuBar)
calculator_window.mainloop()
